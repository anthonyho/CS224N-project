# %% [markdown]
# # Interactive sentence prediction and attention visualization

# %% [markdown]
# ## Initialize here (might take a minute or two)

# %%
from interactive import load_model
m = load_model()
# Out:
# /usr/local/lib/python2.7/dist-packages/pkg_resources.py:1049: UserWarning: /home/anthony/.python-eggs is writable by group/others and vulnerable to attack when used with get_resource_filename. Consider a more secure location (set with .set_extraction_path or the PYTHON_EGG_CACHE environment variable).
#   warnings.warn(msg, UserWarning)
# 100%|██████████| 400000/400000 [00:50<00:00, 7990.83it/s]
# WARNING:tensorflow:From /home/anthony/tccc/CS224N-project/code/attention.py:70: calling reduce_max (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/anthony/tccc/CS224N-project/code/attention.py:72: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# ...

# %% [markdown]
# ## Predict and visualize sentence here!

# %%
sentence = "Michael Wolff is a total loser who made up stories in order to sell this really boring and untruthful book. He used Sloppy Steve Bannon, who cried when he got fired and begged for his job. Now Sloppy Steve has been dumped like a dog by almost everyone. Too bad!"
m.predict_sentence(sentence)
# Out:
# Predicted probability of toxic = 0.7608
# Predicted probability of severe_toxic = 0.0019
# Predicted probability of obscene = 0.0976
# Predicted probability of threat = 0.0003
# Predicted probability of insult = 0.2728
# Predicted probability of identity_hate = 0.0041
